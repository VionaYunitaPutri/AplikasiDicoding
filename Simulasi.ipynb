# %% [markdown]
# <a href="https://colab.research.google.com/github/Vii2906/AplikasiDicoding/blob/main/Simulasi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0708496a-d2c0-49f1-990c-1d6c9494cbab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0708496a-d2c0-49f1-990c-1d6c9494cbab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install scikit-learn joblib pillow matplotlib

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'archive (1).zip', 'weapons', 'archive.zip', 'sample_data']

# %%
import os
import csv
import zipfile
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from PIL import Image
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    ConfusionMatrixDisplay
)
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import joblib

# %%
# ─────────────────────────────────────────────────────────────
# KONFIGURASI
# ─────────────────────────────────────────────────────────────

ZIP_PATH       = "archive.zip"
DATASET_DIR    = "weapons"
IMG_DIR        = os.path.join(DATASET_DIR, "Images")
LABEL_CSV      = os.path.join(DATASET_DIR, "train_labels.csv")

IMG_SIZE       = (64, 64)
N_ESTIMATORS   = 100
MAX_DEPTH      = None
TEST_SIZE      = 0.2
RANDOM_STATE   = 42

MODEL_PATH     = "weapons_rf_model.pkl"

# %%
def extract_dataset():

    if not os.path.exists(DATASET_DIR):

        if os.path.exists(ZIP_PATH):

            print(f"[INFO] Mengekstrak {ZIP_PATH}...")

            with zipfile.ZipFile(ZIP_PATH, "r") as zf:
                zf.extractall(".")

            print("[INFO] Ekstraksi selesai.")

        else:
            raise FileNotFoundError(
                f"File {ZIP_PATH} tidak ditemukan"
            )

    else:
        print(f"[INFO] Folder '{DATASET_DIR}' sudah ada.")

# %%
extract_dataset()

print("\nIsi folder sekarang:")
print(os.listdir())
# Out:
# [INFO] Folder 'weapons' sudah ada.
#
# Isi folder sekarang:
# ['.config', 'archive (1).zip', 'weapons', 'archive.zip', 'sample_data']

# %%
print("\nIsi folder weapons:")
print(os.listdir("weapons"))

print("\nIsi folder Images:")
print(os.listdir("weapons/Images")[:5])
# Out:
# Isi folder weapons:
# ['Images', 'train_labels.csv']
#
# Isi folder Images:
# ['armas (441).jpg', 'armas (2575).jpg', 'armas (482).jpg', 'armas (581).jpg', 'armas (793).jpg']
